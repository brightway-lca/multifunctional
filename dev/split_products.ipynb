# %%
import bw2data as bd
import bw2calc as bc
import multifunctional as mf

# %% [markdown]
# # Create a basic database with a separate product
#
# Note the node type `multifunctional` and the edge attribute `functional`.

# %%
if "multifunctional-products-example" in bd.projects:
    bd.projects.delete_project("multifunctional-products-example", True)

# %%
bd.projects.set_current("multifunctional-products-example")

# %%
PRODUCT_DATA = {
    ("products", "a"): {
        "name": "flow - a",
        "code": "a",
        "unit": "kg",
        "type": "emission",
        "categories": ("air",),
    },
    ("products", "product"): {
        "type": "product",
        "name": "first product",
        "unit": "kg",
        "exchanges": [],
    },
    ("products", "1"): {
        "name": "process - 1",
        "code": "1",
        "location": "first",
        "type": "multifunctional",
        "exchanges": [
            {
                "functional": True,
                "type": "production",
                "code": "product",
                "amount": 4,
                "properties": {
                    "price": 7,
                    "mass": 6,
                },
            },
            {
                "functional": True,
                "type": "production",
                "name": "second product - 1",
                "unit": "megajoule",
                "amount": 6,
                "properties": {
                    "price": 12,
                    "mass": 4,
                },
            },
            {
                "type": "biosphere",
                "name": "flow - a",
                "amount": 10,
                "input": ("products", "a"),
            },
        ],
    },
}

db = mf.MultifunctionalDatabase("products")
db.register(default_allocation="price")
db.write(PRODUCT_DATA)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11629.31it/s]
# 2024-07-05 08:29:22.156 | DEBUG    | multifunctional.node_classes:allocate:72 - Allocating Multifunctional: 'process - 1' (None, first, None) (id: 3) with strategy price
# 2024-07-05 08:29:22.159 | DEBUG    | multifunctional.allocation:generic_allocation:39 - Using allocation factor 0.28 for functional edge Exchange: 4 kg 'first product' (kg, None, None) to Multifunctional: 'process - 1' (None, first, None)> on activity Multifunctional: 'process - 1' (None, first, None)
# 2024-07-05 08:29:22.162 | DEBUG    | multifunctional.allocation:generic_allocation:69 - Creating new product code 9481639facba4b248d96995e60fc9bf6 for functional edge Exchange: 4 kg 'first product' (kg, None, None) to Multifunctional: 'process - 1' (None, first, None)> on activity Multifunctional: 'process - 1' (None, first, None)
# 2024-07-05 08:29:22.163 | DEBUG    | multifunctional.allocation:generic_allocation:39 - Using allocation factor 0.72 for functional edge Exchange: 6 None Multifunctional: 'process - 1' (None, first, None) to Multifunctional: 'process - 1' (None, first, None)> on activity Multifunctional: 'process - 1' (None, first, None)
# 2024-07-05 08:29:22.165 | DEBUG    | multifunctional.allocation:generic_allocation:69 - Creating new product code eca8cb2842474f6eac4c488b266fd2ed for functional edge Exchange: 6 None Multifunctional: 'process - 1' (None, first, None) to Multifunctional: 'process - 1' (None, first, None)> on activity Multifunctional: 'process - 1' (None, first, None)
# Vacuuming database

# %% [markdown]
# Writing the database also allocates the multifunctional process:

# %%
for node in bd.Database("products"):
    print(node, node['type'])
# Out:
# Multifunctional: 'process - 1' (None, first, None) multifunctional
# 'first product' (kg, None, None) product
# 'flow - a' (kg, None, ('air',)) emission
# Read-only allocated process: 'process - 1' (kg, first, None) readonly_process
# Read-only allocated process: 'process - 1' (megajoule, first, None) readonly_process

# %% [markdown]
# Links to the `product` node are preserved:

# %%
for exc in bd.get_node(name="process - 1", unit="kg", database="products").production():
    print(exc)
# Out:
# Exchange: 4 kg 'first product' (kg, None, None) to Read-only allocated process: 'process - 1' (kg, first, None)>

# %% [markdown]
# The product node can be used in LCIA:

# %%
m = bd.Method(("foo",))
m.register()
m.write([(bd.get_node(code="a").id, 5)])

# %%
fu, objs, _ = bd.prepare_lca_inputs(
    demand={bd.get_node(name="first product"): 1}, method=("foo",)
)
lca = bc.LCA(fu, data_objs=objs)
lca.lci()
lca.lcia()
lca.score
# Out:
# 3.4999999403953552
