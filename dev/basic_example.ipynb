# %%
import bw2data as bd
import bw2calc as bc
import multifunctional as mf

# %% [markdown]
# # Create a basic database
#
# Note the node type `multifunctional` and the edge attribute `functional`.

# %%
if "multifunctional-example" in bd.projects:
    bd.projects.delete_project("multifunctional-example", True)

# %%
bd.projects.set_current("multifunctional-example")

# %%
BASIC_DATA = {
    ("basic", "a"): {
        "name": "flow - a",
        "code": "a",
        "unit": "kg",
        "type": "emission",
        "categories": ("air",),
    },
    ("basic", "1"): {
        "name": "process - 1",
        "code": "1",
        "location": "first",
        "type": "multifunctional",
        "exchanges": [
            {
                "functional": True,
                "type": "production",
                "name": "first product - 1",
                "unit": "kg",
                "amount": 4,
                "properties": {
                    "price": 7,
                    "mass": 6,
                },
            },
            {
                "functional": True,
                "type": "production",
                "name": "second product - 1",
                "unit": "megajoule",
                "amount": 6,
                "properties": {
                    "price": 12,
                    "mass": 4,
                },
            },
            {
                "type": "biosphere",
                "name": "flow - a",
                "amount": 10,
                "input": ("basic", "a"),
            },
        ],
    },
}

db = mf.MultifunctionalDatabase("basic")
db.register(default_allocation="price")
db.write(BASIC_DATA)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 7869.24it/s]
# 2024-07-04 13:51:24.811 | DEBUG    | multifunctional.node_classes:allocate:68 - Allocating 'process - 1' (None, first, None) (id: 2) with strategy price
# 2024-07-04 13:51:24.813 | DEBUG    | multifunctional.allocation:generic_allocation:37 - Using allocation factor 0.28 for functional edge Exchange: 4 None 'process - 1' (None, first, None) to 'process - 1' (None, first, None)> on activity 'process - 1' (None, first, None)
# 2024-07-04 13:51:24.814 | DEBUG    | multifunctional.allocation:generic_allocation:50 - Creating new product code 5a3ace8e63e54bf994bf422164f57242 for functional edge Exchange: 4 None 'process - 1' (None, first, None) to 'process - 1' (None, first, None)> on activity 'process - 1' (None, first, None)
# 2024-07-04 13:51:24.816 | DEBUG    | multifunctional.allocation:generic_allocation:37 - Using allocation factor 0.72 for functional edge Exchange: 6 None 'process - 1' (None, first, None) to 'process - 1' (None, first, None)> on activity 'process - 1' (None, first, None)
# 2024-07-04 13:51:24.818 | DEBUG    | multifunctional.allocation:generic_allocation:50 - Creating new product code c574fce2e23542a29895ca3b522a29db for functional edge Exchange: 6 None 'process - 1' (None, first, None) to 'process - 1' (None, first, None)> on activity 'process - 1' (None, first, None)
# Vacuuming database

# %% [markdown]
# Writing the database also allocates the multifunctional process:

# %%
for node in bd.Database("basic"):
    print(node, node['type'])
# Out:
# 'process - 1' (kg, first, None) readonly_process
# 'process - 1' (None, first, None) multifunctional
# 'process - 1' (megajoule, first, None) readonly_process
# 'flow - a' (kg, None, ('air',)) emission

# %% [markdown]
# Allocated processes are read-only

# %%
attributes = {"reference product": "first product - 1", "database": "basic"}
node = bd.get_node(**attributes)
node
# Out:
# 'process - 1' (kg, first, None)

# %%
node['foo'] = 'bar'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 node['foo'] = 'bar'
#
# File ~/Code/brightway/multifunctional/multifunctional/node_classes.py:91, in ReadOnlyProcessWithReferenceProduct.__setitem__(self, key, value)
#      90 def __setitem__(self, key, value):
# ---> 91     raise NotImplementedError(
#      92         "This node is read only. Update the corresponding multifunctional process."
#      93     )
#
# NotImplementedError: This node is read only. Update the corresponding multifunctional process.

# %% [markdown]
# But they can be used in LCIA:

# %%
m = bd.Method(("foo",))
m.register()
m.write([(bd.get_node(code="a").id, 5)])

# %%
fu, objs, _ = bd.prepare_lca_inputs(
    demand={node: 1}, method=("foo",)
)
lca = bc.LCA(fu, data_objs=objs)
lca.lci()
lca.lcia()
lca.score
# Out:
# 3.4999999403953552
